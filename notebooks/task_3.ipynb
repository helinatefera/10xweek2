# %% [markdown]
# <a href="https://colab.research.google.com/github/helinatefera/10xweek2/blob/task-3/notebooks/task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

# %%
#read xlssx data
data = pd.read_excel('data.xlsx')
data.head()
# Out:
#               Bearer Id               Start  Start ms                 End  \
# 0  13114483460844900352 2019-04-04 12:01:18     770.0 2019-04-25 14:35:31
# 1  13114483482878900224 2019-04-09 13:04:04     235.0 2019-04-25 08:15:48
# 2  13114483484080500736 2019-04-09 17:42:11       1.0 2019-04-25 11:58:13
# 3  13114483485442799616 2019-04-10 00:31:25     486.0 2019-04-25 07:36:35
# 4  13114483499480700928 2019-04-12 20:10:23     565.0 2019-04-25 10:40:32
#
#    End ms  Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0   662.0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1   606.0  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2   652.0  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3   171.0  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4   954.0  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#   Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# ...

# %%
len(data)
# Out:
# 150001

# %%
#replace null data with mean for numerical and mode for catagorical
data.fillna({
    'TCP DL Retrans. Vol (Bytes)': data['TCP DL Retrans. Vol (Bytes)'].mean(),
    'TCP UL Retrans. Vol (Bytes)': data['TCP UL Retrans. Vol (Bytes)'].mean(),
    'Avg RTT DL (ms)': data['Avg RTT DL (ms)'].mean(),
    'Avg RTT UL (ms)': data['Avg RTT UL (ms)'].mean(),
    'Avg Bearer TP DL (kbps)': data['Avg Bearer TP DL (kbps)'].mean(),
    'Avg Bearer TP UL (kbps)': data['Avg Bearer TP UL (kbps)'].mean(),
    'Handset Type': data['Handset Type'].mode()[0]
}, inplace=True)

# %% [markdown]
# The **Average RTT (Round Trip Time)** is a measure of the time it takes for data to travel from the user device to the server and back.

# %%
# Calculate Average RTT
data['Average RTT (ms)'] = (data['Avg RTT DL (ms)'] + data['Avg RTT UL (ms)']) / 2

# %%
data[['Avg RTT DL (ms)', 'Avg RTT UL (ms)', 'Average RTT (ms)']].head()
# Out:
#    Avg RTT DL (ms)  Avg RTT UL (ms)  Average RTT (ms)
# 0        42.000000         5.000000         23.500000
# 1        65.000000         5.000000         35.000000
# 2       109.795706        17.662883         63.729294
# 3       109.795706        17.662883         63.729294
# 4       109.795706        17.662883         63.729294
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Avg RTT DL (ms)'].plot(kind='hist', bins=20, title='Avg RTT DL (ms)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Avg RTT UL (ms)'].plot(kind='hist', bins=20, title='Avg RTT UL (ms)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Average RTT (ms)'].plot(kind='hist', bins=20, title='Average RTT (ms)')
# ...

# %% [markdown]
# - **High RTT values** indicate network delays, which can result in poor user experiences (e.g., slow loading times, buffering).
# - **Low RTT values** signify better network performance and faster responses.

# %%
data['Average TCP Retransmission (Bytes)'] = (data['TCP DL Retrans. Vol (Bytes)'] + data['TCP UL Retrans. Vol (Bytes)']) / 2

# %%
data['Average Throughput (kbps)'] = (data['Avg Bearer TP DL (kbps)'] + data['Avg Bearer TP UL (kbps)']) / 2

# %%
# Group by MSISDN
aggregated_data = data.groupby('MSISDN/Number').agg({
    'Average TCP Retransmission (Bytes)': 'mean',
    'Average RTT (ms)': 'mean',
    'Average Throughput (kbps)': 'mean',
    'Handset Type': lambda x: x.mode()[0]  # Most frequent handset type
}).reset_index()

# %%
aggregated_data
# Out:
#         MSISDN/Number  Average TCP Retransmission (Bytes)  Average RTT (ms)  \
# 0        3.360100e+10                        1.078479e+07         23.000000
# 1        3.360100e+10                        1.078479e+07         15.500000
# 2        3.360100e+10                        1.078479e+07         63.729294
# 3        3.360101e+10                        3.803623e+05         42.000000
# 4        3.360101e+10                        7.735101e+06         29.750000
# ...               ...                                 ...               ...
# 106851   3.379000e+10                        1.090225e+05         26.000000
# 106852   3.379000e+10                        1.078479e+07         20.000000
# 106853   3.197021e+12                        1.078479e+07         63.729294
# 106854   3.370000e+14                        1.078479e+07         63.729294
# 106855   8.823971e+14                        1.078479e+07         63.729294
#
# ...
