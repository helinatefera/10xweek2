# %% [markdown]
# <a href="https://colab.research.google.com/github/helinatefera/10xweek2/blob/task-2/notebooks/task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# 2                D42335A  ...          19725661.0          14699576.0
# 3                T21824A  ...          21388122.0          15146643.0
# 4                D88865A  ...          15259380.0          18962873.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 55 columns]

# %%
len(data)
# Out:
# 22394

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22394 entries, 0 to 22393
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Bearer Id                                 22046 non-null  float64
#  1   Start                                     22393 non-null  object
#  2   Start ms                                  22393 non-null  float64
#  3   End                                       22393 non-null  object
#  4   End ms                                    22393 non-null  float64
#  5   Dur. (ms)                                 22393 non-null  float64
#  6   IMSI                                      22234 non-null  float64
#  7   MSISDN/Number                             22080 non-null  float64
#  8   IMEI                                      22234 non-null  float64
#  9   Last Location Name                        21970 non-null  object
#  10  Avg RTT DL (ms)                           20974 non-null  float64
#  11  Avg RTT UL (ms)                           20977 non-null  float64
#  12  Avg Bearer TP DL (kbps)                   22393 non-null  float64
#  13  Avg Bearer TP UL (kbps)                   22393 non-null  float64
#  14  TCP DL Retrans. Vol (Bytes)               13744 non-null  float64
#  15  TCP UL Retrans. Vol (Bytes)               11443 non-null  float64
#  16  DL TP < 50 Kbps (%)                       22199 non-null  float64
#  17  50 Kbps < DL TP < 250 Kbps (%)            22199 non-null  float64
#  18  250 Kbps < DL TP < 1 Mbps (%)             22199 non-null  float64
#  19  DL TP > 1 Mbps (%)                        22199 non-null  float64
#  20  UL TP < 10 Kbps (%)                       22257 non-null  float64
#  21  10 Kbps < UL TP < 50 Kbps (%)             22257 non-null  float64
#  22  50 Kbps < UL TP < 300 Kbps (%)            22257 non-null  float64
#  23  UL TP > 300 Kbps (%)                      22257 non-null  float64
#  24  HTTP DL (Bytes)                           15268 non-null  float64
#  25  HTTP UL (Bytes)                           15239 non-null  float64
#  26  Activity Duration DL (ms)                 22393 non-null  float64
#  27  Activity Duration UL (ms)                 22393 non-null  float64
#  28  Dur. (ms).1                               22393 non-null  float64
#  29  Handset Manufacturer                      22234 non-null  object
#  30  Handset Type                              22234 non-null  object
#  31  Nb of sec with 125000B < Vol DL           11070 non-null  float64
#  32  Nb of sec with 1250B < Vol UL < 6250B     12157 non-null  float64
#  33  Nb of sec with 31250B < Vol DL < 125000B  12173 non-null  float64
#  34  Nb of sec with 37500B < Vol UL            3290 non-null   float64
#  35  Nb of sec with 6250B < Vol DL < 31250B    13634 non-null  float64
#  36  Nb of sec with 6250B < Vol UL < 37500B    7129 non-null   float64
#  37  Nb of sec with Vol DL < 6250B             22199 non-null  float64
#  38  Nb of sec with Vol UL < 1250B             22257 non-null  float64
#  39  Social Media DL (Bytes)                   22393 non-null  float64
#  40  Social Media UL (Bytes)                   22393 non-null  float64
#  41  Google DL (Bytes)                         22393 non-null  float64
#  42  Google UL (Bytes)                         22393 non-null  float64
#  43  Email DL (Bytes)                          22393 non-null  float64
#  44  Email UL (Bytes)                          22393 non-null  float64
#  45  Youtube DL (Bytes)                        22393 non-null  float64
#  46  Youtube UL (Bytes)                        22393 non-null  float64
#  47  Netflix DL (Bytes)                        22393 non-null  float64
#  48  Netflix UL (Bytes)                        22393 non-null  float64
#  49  Gaming DL (Bytes)                         22393 non-null  float64
#  50  Gaming UL (Bytes)                         22393 non-null  float64
#  51  Other DL (Bytes)                          22393 non-null  float64
#  52  Other UL (Bytes)                          22393 non-null  float64
#  53  Total UL (Bytes)                          22393 non-null  float64
#  54  Total DL (Bytes)                          22393 non-null  float64
# dtypes: float64(50), object(5)
# memory usage: 9.4+ MB

# %%
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data Heatmap')
plt.show()

# %%
# Count of missing values for each column
missing_values = data.isnull().sum()

# Percentage of missing values for each column
missing_percentage = (missing_values / len(data)) * 100

# Get the columns to drop (those with >70% missing values)
columns_to_drop = missing_percentage[missing_percentage > 70].index

# Drop the columns in one go
data = data.drop(columns=columns_to_drop)

# %%
len(data.columns)
# Out:
# 54

# %% [markdown]
# ## Top 10 handsets used by the customers.

# %%
# Group by 'Handset Manufacturer' and count occurrences
top_handsets = data['Handset Manufacturer'].value_counts().head(10)

# %%
top_handsets
# Out:
# Handset Manufacturer
# Apple                                   10207
# Samsung                                  4856
# Huawei                                   4335
# undefined                                 996
# Sony Mobile Communications Ab             329
# Wiko Global Sasu                          210
# Xiaomi Communications Co Ltd              163
# Oneplus Technology (Shenzhen) Co Ltd      124
# Asustek                                   122
# Lenovo                                     96
# Name: count, dtype: int64

# %% [markdown]
# **Results Interpretation:**
# The result should show that Apple is the most frequently used handset manufacturer, followed by Samsung and Huawei. The others, like Xiaomi, Oneplus, and Lenovo, are relatively less common.
#
# Let me know if you'd like to explore the data further!

# %%
# Top handsets Type
top_handsets = data['Handset Type'].value_counts().head(10)
top_handsets
# Out:
# Handset Type
# Huawei B528S-23A                2133
# Apple iPhone 6 (A1586)          1701
# Apple iPhone 6S (A1688)         1347
# Apple iPhone 7 (A1778)          1319
# undefined                        996
# Apple iPhone Se (A1723)          843
# Apple iPhone 8 (A1905)           824
# Apple iPhone X (A1901)           646
# Apple iPhone Xr (A2105)          541
# Samsung Galaxy S8 (Sm-G950F)     494
# Name: count, dtype: int64

# %%
top_manufacturers = ['Apple', 'Samsung', 'Huawei']
filtered_data = data[data['Handset Manufacturer'].isin(top_manufacturers)]
top_5_handsets_per_manufacturer = {}
for manufacturer in top_manufacturers:
    manufacturer_data = filtered_data[filtered_data['Handset Manufacturer'] == manufacturer]
    top_5_handsets = manufacturer_data['Handset Type'].value_counts().head(5)
    top_5_handsets_per_manufacturer[manufacturer] = top_5_handsets
for manufacturer, handsets in top_5_handsets_per_manufacturer.items():
    print(f"{manufacturer}:")
    print(handsets)
# Out:
# Apple:
# Handset Type
# Apple iPhone 6 (A1586)     1701
# Apple iPhone 6S (A1688)    1347
# Apple iPhone 7 (A1778)     1319
# Apple iPhone Se (A1723)     843
# Apple iPhone 8 (A1905)      824
# Name: count, dtype: int64
# Samsung:
# Handset Type
# Samsung Galaxy S8 (Sm-G950F)         494
# Samsung Galaxy S7 (Sm-G930X)         373
# Samsung Galaxy A5 Sm-A520F           323
# Samsung Galaxy S7 Edge (Sm-G935X)    272
# Samsung Galaxy J3 (Sm-J330)          270
# Name: count, dtype: int64
# Huawei:
# Handset Type
# Huawei B528S-23A                  2133
# Huawei P20 Lite Huawei Nova 3E     218
# Huawei E5180                       216
# Huawei P8 Lite                     178
# Huawei P20                         164
# Name: count, dtype: int64

# %% [markdown]
# ### **Interpretation**:
# - **Apple**: The dominance of older iPhone models (iPhone 6, 6S, and 7) suggests a loyal customer base, potentially focused on cost-effective upgrades or replacement rather than switching to newer models. The iPhone Xr and X models indicate some interest in newer releases but at a smaller scale.
#
# - **Samsung**: The top handsets are a mix of high-end (Galaxy S8, S7) and mid-range models (A5, J3), showing Samsung's broad appeal across different customer segments. However, the numbers are lower compared to Apple, indicating potential room for more market penetration.
#
# - **Huawei**: The Huawei B528S-23A handset dominates, highlighting strong brand presence in specific product lines. However, the rest of their models (P20, Y6) show limited customer engagement, which could signal a need for better-targeted campaigns.
#
# ### **Recommendations**:
# - **Apple**: Target marketing efforts on providing attractive offers or trade-in deals for older iPhone models (6, 6S, 7) to upgrade to the latest models, possibly with incentives or discounts.
#
# - **Samsung**: Focus on promoting the Galaxy S series and A series models to cater to both premium and budget-conscious customers. More emphasis on product differentiation may help increase sales in emerging markets.
#
# - **Huawei**: Leverage the popularity of the B528S-23A for targeted campaigns but consider improving visibility for other models like the P20 and Y6 through influencer partnerships and promotions to drive higher engagement.

# %% [markdown]
# # **Task one**

# %%
# Aggregating the data for each user
aggregated_data = data.groupby('IMSI').agg(
    number_of_sessions=('Bearer Id', 'nunique'),  # Count of unique xDR sessions per user
    total_session_duration_dl=('Activity Duration DL (ms)', 'sum'),  # Total download duration
    total_session_duration_ul=('Activity Duration UL (ms)', 'sum'),  # Total upload duration
    total_social_media_dl=('Social Media DL (Bytes)', 'sum'),
    total_social_media_ul=('Social Media UL (Bytes)', 'sum'),
    total_google_dl=('Google DL (Bytes)', 'sum'),
    total_google_ul=('Google UL (Bytes)', 'sum'),
    total_youtube_dl=('Youtube DL (Bytes)', 'sum'),
    total_youtube_ul=('Youtube UL (Bytes)', 'sum'),
    total_netflix_dl=('Netflix DL (Bytes)', 'sum'),
    total_netflix_ul=('Netflix UL (Bytes)', 'sum'),
    total_gaming_dl=('Gaming DL (Bytes)', 'sum'),
    total_gaming_ul=('Gaming UL (Bytes)', 'sum'),
    total_email_dl=('Email DL (Bytes)', 'sum'),
    total_email_ul=('Email UL (Bytes)', 'sum'),
    total_others_dl=('Other DL (Bytes)', 'sum'),
    total_others_ul=('Other UL (Bytes)', 'sum')
).reset_index()

# %%
aggregated_data.head()
# Out:
#            IMSI  number_of_sessions  total_session_duration_dl  \
# 0  2.082001e+14                   1                      740.0
# 1  2.082001e+14                   2                   692301.0
# 2  2.082002e+14                   1                    53767.0
# 3  2.082002e+14                   1                  1443125.0
# 4  2.082003e+14                   2                   306078.0
#
#    total_session_duration_ul  total_social_media_dl  total_social_media_ul  \
# 0                     1052.0               996268.0                55565.0
# 1                   718974.0              1901280.0                91157.0
# 2                    47158.0              1140106.0                30177.0
# 3                   404803.0              2964044.0                52989.0
# 4                   320612.0              4008990.0                57684.0
#
#    total_google_dl  total_google_ul  total_youtube_dl  total_youtube_ul  \
# 0        9712501.0        3562840.0        14819244.0         4777564.0
# 1       14707482.0        3718211.0        23540751.0        16183062.0
# 2       10449647.0        3457153.0         8448552.0        16417599.0
# 3        7096184.0        2667120.0        21263080.0         1923718.0
# 4       18091345.0        3358331.0        32062537.0        20046309.0
#
#    total_netflix_dl  total_netflix_ul  total_gaming_dl  total_gaming_ul  \
# 0        15494900.0        18682284.0     6.214597e+08       11285996.0
# 1        28574223.0        22852422.0     1.237717e+09       29148727.0
# 2        10549392.0        20292382.0     1.743606e+08       13117413.0
# 3        19862420.0         2173329.0     2.431142e+07        6918930.0
# 4        30597167.0        14507596.0     5.075693e+08       24013895.0
#
#    total_email_dl  total_email_ul  total_others_dl  total_others_ul
# 0       3110793.0        328100.0     5.487023e+08         519932.0
# 1       2358866.0        873353.0     6.555374e+08       17422326.0
# 2       2238455.0        643834.0     6.287683e+08       14897654.0
# 3       1044625.0        861424.0     3.495839e+08        3065986.0
# 4       2250987.0        372426.0     1.153546e+09       23181874.0

# %% [markdown]
# **Heavy Data Consumers:**
#
# - **User 2** has the highest total session duration and the largest data consumption across all applications, especially in Google, YouTube, and Netflix.
# -  **User 1** also stands out for their high data consumption in video apps like YouTube and Netflix.

# %%
statistics = data.describe()
print(statistics)
# Out:
#           Bearer Id      Start ms        End ms     Dur. (ms)          IMSI  \
# count  2.204600e+04  22393.000000  22393.000000  2.239300e+04  2.223400e+04
# mean   1.019878e+19    498.749029    499.085027  4.239016e+04  2.082016e+14
# std    2.901880e+18    288.991194    286.711986  4.749628e+04  1.238229e+09
# min    7.200000e+00      0.000000      0.000000  8.937000e+03  2.082001e+14
# 25%    7.277826e+18    249.000000    251.000000  2.027300e+04  2.082010e+14
# 50%    1.268214e+19    498.000000    498.000000  2.959200e+04  2.082015e+14
# 75%    1.304243e+19    750.000000    745.000000  5.368100e+04  2.082018e+14
# max    1.318654e+19    999.000000    999.000000  1.823652e+06  2.082099e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   2.208000e+04  2.223400e+04     20974.000000     20977.000000
# mean    3.367384e+10  4.704017e+13       166.202250        17.165896
# std     4.560739e+07  2.173754e+13       834.298814        86.219064
# min     3.360101e+10  1.202601e+12         6.000000         0.000000
# 25%     3.365067e+10  3.546071e+13        36.000000         3.000000
# 50%     3.366356e+10  3.568081e+13        50.000000         6.000000
# 75%     3.368227e+10  3.594871e+13        81.000000        14.000000
# max     3.378998e+10  9.900120e+13     55811.000000      7120.000000
#
#        Avg Bearer TP DL (kbps)  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# count             22393.000000  ...        2.239300e+04        2.239300e+04
# mean              17071.964542  ...        1.158876e+07        1.097757e+07
# std               24791.346650  ...        6.719355e+06        6.348655e+06
# min                   0.000000  ...        1.224000e+03        1.050000e+02
# 25%                  56.000000  ...        5.724643e+06        5.499157e+06
# 50%                4880.000000  ...        1.157667e+07        1.092986e+07
# 75%               26781.000000  ...        1.745956e+07        1.649038e+07
# max              231748.000000  ...        2.325829e+07        2.201196e+07
#
#        Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# count        2.239300e+04        2.239300e+04       2.239300e+04
# mean         1.165613e+07        1.092162e+07       4.213684e+08
# std          6.704041e+06        6.345613e+06       2.442911e+08
# min          4.200000e+01        2.430000e+02       1.251100e+04
# 25%          5.786671e+06        5.417247e+06       2.115481e+08
# 50%          1.164327e+07        1.081570e+07       4.220086e+08
# 75%          1.742106e+07        1.636691e+07       6.322429e+08
# max          2.325830e+07        2.201166e+07       8.434419e+08
#
#        Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# count       2.239300e+04      2.239300e+04      2.239300e+04
# mean        8.223652e+06      4.190617e+08      8.289540e+06
# std         4.779960e+06      2.419615e+08      4.757270e+06
# min         2.280000e+02      6.475700e+04      1.287000e+03
# 25%         4.066803e+06      2.088954e+08      4.175248e+06
# 50%         8.196012e+06      4.204200e+08      8.281258e+06
# 75%         1.233627e+07      6.270234e+08      1.238910e+07
# max         1.655718e+07      8.433675e+08      1.655731e+07
#
#        Total UL (Bytes)  Total DL (Bytes)
# count      2.239300e+04      2.239300e+04
# mean       4.096291e+07      4.539958e+08
# std        1.122135e+07      2.444882e+08
# min        4.469240e+06      7.114041e+06
# 25%        3.294448e+07      2.448883e+08
# 50%        4.092307e+07      4.547952e+08
# 75%        4.887295e+07      6.653188e+08
# max        7.833131e+07      8.964337e+08
#
# [8 rows x 49 columns]

# %% [markdown]
# # **Segmenting Users into Top Five Decile Classes Based on Total Duration**

# %%
# Calculate total duration for each user
data['total_duration'] = data.groupby('IMSI')['Dur. (ms).1'].transform('sum')

# Segment into deciles based on total duration
data['duration_decile'] = pd.qcut(data['total_duration'], 10, labels=False) + 1

# Compute total data usage (DL + UL) per user
data['total_data'] = data['Total DL (Bytes)'] + data['Total UL (Bytes)']

# Aggregate total data by decile class
decile_data = data.groupby('duration_decile')['total_data'].sum().reset_index()

# Output the total data per decile class
print(decile_data)
# Out:
#    duration_decile    total_data
# 0              1.0  1.116896e+12
# 1              2.0  1.103059e+12
# 2              3.0  1.095730e+12
# 3              4.0  1.094169e+12
# 4              5.0  1.116213e+12
# 5              6.0  1.089590e+12
# 6              7.0  1.096910e+12
# 7              8.0  1.107411e+12
# 8              9.0  1.073483e+12
# 9             10.0  1.109074e+12

# %% [markdown]
# **Decile segmentation** allows you to categorize users based on their engagement level with the system. By computing the total data usage for each decile, you can identify high-usage segments (top deciles) that consume more resources, which could help in targeting high-value users for personalized services or improving network infrastructure.

# %%
summary_stats = data[['Dur. (ms).1', 'Total DL (Bytes)', 'Total UL (Bytes)', 'Avg RTT DL (ms)', 'Avg RTT UL (ms)']].describe()
summary_stats
# Out:
#         Dur. (ms).1  Total DL (Bytes)  Total UL (Bytes)  Avg RTT DL (ms)  \
# count  2.239300e+04      2.239300e+04      2.239300e+04     20974.000000
# mean   4.239069e+07      4.539958e+08      4.096291e+07       166.202250
# std    4.749631e+07      2.444882e+08      1.122135e+07       834.298814
# min    8.937157e+06      7.114041e+06      4.469240e+06         6.000000
# 25%    2.027393e+07      2.448883e+08      3.294448e+07        36.000000
# 50%    2.959215e+07      4.547952e+08      4.092307e+07        50.000000
# 75%    5.368117e+07      6.653188e+08      4.887295e+07        81.000000
# max    1.823653e+09      8.964337e+08      7.833131e+07     55811.000000
#
#        Avg RTT UL (ms)
# count     20977.000000
# mean         17.165896
# std          86.219064
# min           0.000000
# 25%           3.000000
# 50%           6.000000
# 75%          14.000000
# max        7120.000000

# %% [markdown]
# ## Non-Graphical Univariate Analysis

# %%
dispersion_metrics = data[['Dur. (ms).1', 'Total DL (Bytes)', 'Total UL (Bytes)', 'Avg RTT DL (ms)', 'Avg RTT UL (ms)']].agg(['var', 'std'])
dispersion_metrics
# Out:
#       Dur. (ms).1  Total DL (Bytes)  Total UL (Bytes)  Avg RTT DL (ms)  \
# var  2.255899e+15      5.977448e+16      1.259187e+14    696054.511136
# std  4.749631e+07      2.444882e+08      1.122135e+07       834.298814
#
#      Avg RTT UL (ms)
# var      7433.726959
# std        86.219064

# %% [markdown]
# # Graphical Univariate Analysis

# %%
# Histogram for Total Duration
sns.histplot(data['Dur. (ms).1'], kde=True)
plt.title('Distribution of Session Duration')
plt.xlabel('Session Duration (seconds)')
plt.ylabel('Frequency')
plt.show()

# Boxplot for RTT Downlink
sns.boxplot(data=data['Avg RTT DL (ms)'])
plt.title('RTT Downlink Distribution')
plt.xlabel('Average RTT DL (ms)')
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
# Scatter plot of Social Media Data vs Total Data
sns.scatterplot(x=data['Social Media DL (Bytes)'] + data['Social Media UL (Bytes)'], y=data['Total DL (Bytes)'] + data['Total UL (Bytes)'])
plt.title('Social Media Data vs Total Data Usage')
plt.xlabel('Social Media Data (DL + UL)')
plt.ylabel('Total Data Usage (DL + UL)')
plt.show()

# Correlation for each application with Total Data
correlation_data = data[['Social Media DL (Bytes)', 'Google DL (Bytes)', 'Email DL (Bytes)', 'Youtube DL (Bytes)', 'Netflix DL (Bytes)', 'Gaming DL (Bytes)', 'Other DL (Bytes)', 'Total DL (Bytes)', 'Total UL (Bytes)']].corr()
correlation_data
# Out:
#                          Social Media DL (Bytes)  Google DL (Bytes)  \
# Social Media DL (Bytes)                 1.000000           0.006957
# Google DL (Bytes)                       0.006957           1.000000
# Email DL (Bytes)                       -0.000581          -0.008370
# Youtube DL (Bytes)                     -0.013961           0.002390
# Netflix DL (Bytes)                      0.000517          -0.002862
# Gaming DL (Bytes)                      -0.008680           0.005164
# Other DL (Bytes)                        0.003481           0.004865
# Total DL (Bytes)                       -0.004739           0.018686
# Total UL (Bytes)                        0.004815           0.003185
#
#                          Email DL (Bytes)  Youtube DL (Bytes)  \
# Social Media DL (Bytes)         -0.000581           -0.013961
# Google DL (Bytes)               -0.008370            0.002390
# Email DL (Bytes)                 1.000000           -0.008362
# Youtube DL (Bytes)              -0.008362            1.000000
# Netflix DL (Bytes)               0.009915           -0.004273
# Gaming DL (Bytes)                0.006643           -0.005240
# Other DL (Bytes)                -0.012657           -0.014389
# Total DL (Bytes)                 0.010797            0.022068
# Total UL (Bytes)                 0.005926           -0.005047
#
#                          Netflix DL (Bytes)  Gaming DL (Bytes)  \
# Social Media DL (Bytes)            0.000517          -0.008680
# Google DL (Bytes)                 -0.002862           0.005164
# Email DL (Bytes)                   0.009915           0.006643
# Youtube DL (Bytes)                -0.004273          -0.005240
# Netflix DL (Bytes)                 1.000000           0.001089
# Gaming DL (Bytes)                  0.001089           1.000000
# Other DL (Bytes)                  -0.005053           0.011678
# Total DL (Bytes)                   0.028397           0.999141
# Total UL (Bytes)                  -0.002069           0.006635
#
#                          Other DL (Bytes)  Total DL (Bytes)  Total UL (Bytes)
# Social Media DL (Bytes)          0.003481         -0.004739          0.004815
# Google DL (Bytes)                0.004865          0.018686          0.003185
# Email DL (Bytes)                -0.012657          0.010797          0.005926
# Youtube DL (Bytes)              -0.014389          0.022068         -0.005047
# Netflix DL (Bytes)              -0.005053          0.028397         -0.002069
# Gaming DL (Bytes)                0.011678          0.999141          0.006635
# Other DL (Bytes)                 1.000000          0.011162         -0.005893
# Total DL (Bytes)                 0.011162          1.000000          0.006523
# Total UL (Bytes)                -0.005893          0.006523          1.000000

# %%
# Correlation matrix for specified variables
corr_matrix = data[['Social Media DL (Bytes)', 'Google DL (Bytes)', 'Email DL (Bytes)', 'Youtube DL (Bytes)', 'Netflix DL (Bytes)', 'Gaming DL (Bytes)', 'Other DL (Bytes)', 'Total DL (Bytes)', 'Total UL (Bytes)']].corr()
corr_matrix
# Out:
#                          Social Media DL (Bytes)  Google DL (Bytes)  \
# Social Media DL (Bytes)                 1.000000           0.006957
# Google DL (Bytes)                       0.006957           1.000000
# Email DL (Bytes)                       -0.000581          -0.008370
# Youtube DL (Bytes)                     -0.013961           0.002390
# Netflix DL (Bytes)                      0.000517          -0.002862
# Gaming DL (Bytes)                      -0.008680           0.005164
# Other DL (Bytes)                        0.003481           0.004865
# Total DL (Bytes)                       -0.004739           0.018686
# Total UL (Bytes)                        0.004815           0.003185
#
#                          Email DL (Bytes)  Youtube DL (Bytes)  \
# Social Media DL (Bytes)         -0.000581           -0.013961
# Google DL (Bytes)               -0.008370            0.002390
# Email DL (Bytes)                 1.000000           -0.008362
# Youtube DL (Bytes)              -0.008362            1.000000
# Netflix DL (Bytes)               0.009915           -0.004273
# Gaming DL (Bytes)                0.006643           -0.005240
# Other DL (Bytes)                -0.012657           -0.014389
# Total DL (Bytes)                 0.010797            0.022068
# Total UL (Bytes)                 0.005926           -0.005047
#
#                          Netflix DL (Bytes)  Gaming DL (Bytes)  \
# Social Media DL (Bytes)            0.000517          -0.008680
# Google DL (Bytes)                 -0.002862           0.005164
# Email DL (Bytes)                   0.009915           0.006643
# Youtube DL (Bytes)                -0.004273          -0.005240
# Netflix DL (Bytes)                 1.000000           0.001089
# Gaming DL (Bytes)                  0.001089           1.000000
# Other DL (Bytes)                  -0.005053           0.011678
# Total DL (Bytes)                   0.028397           0.999141
# Total UL (Bytes)                  -0.002069           0.006635
#
#                          Other DL (Bytes)  Total DL (Bytes)  Total UL (Bytes)
# Social Media DL (Bytes)          0.003481         -0.004739          0.004815
# Google DL (Bytes)                0.004865          0.018686          0.003185
# Email DL (Bytes)                -0.012657          0.010797          0.005926
# Youtube DL (Bytes)              -0.014389          0.022068         -0.005047
# Netflix DL (Bytes)              -0.005053          0.028397         -0.002069
# Gaming DL (Bytes)                0.011678          0.999141          0.006635
# Other DL (Bytes)                 1.000000          0.011162         -0.005893
# Total DL (Bytes)                 0.011162          1.000000          0.006523
# Total UL (Bytes)                -0.005893          0.006523          1.000000

# %% [markdown]
# ### Correlation Matrix Interpretation
#
# The correlation matrix you've provided shows the relationship between different data variables. Here's an analysis of the correlations and their potential significance:
#
# #### Key Observations:
# 1. **Strong Positive Correlation Between `Gaming DL (Bytes)` and `Total DL (Bytes)`**:
#    - The correlation value of **0.999** between `Gaming DL (Bytes)` and `Total DL (Bytes)` is extremely high. This suggests that the total data volume sent and received for gaming is nearly equivalent to the total downlink (DL) data. This could indicate that most of the traffic under `Total DL` is driven by gaming activities.
#
# 2. **Moderate Correlation Between `Netflix DL (Bytes)` and `Total DL (Bytes)`**:
#    - The correlation value of **0.028** between `Netflix DL (Bytes)` and `Total DL (Bytes)` is low, suggesting that Netflix traffic has a minimal effect on the total downlink data in the dataset. This indicates that Netflix may not be a significant contributor to the overall downlink data compared to other categories like gaming.
#
# 3. **Weak Correlations in Most Other Variables**:
#    - Variables like **Social Media DL (Bytes)**, **Google DL (Bytes)**, and **Email DL (Bytes)** exhibit weak correlations with `Total DL (Bytes)` (values close to 0), suggesting that these activities have minimal overlap in terms of data volume with the total downlink.
#
# 4. **Negative Correlation Between `Youtube DL (Bytes)` and `Social Media DL (Bytes)`**:
#    - The correlation value of **-0.01396** suggests a very weak negative relationship between YouTube and social media data. This implies that in some cases, users who consume YouTube content might consume slightly less social media data or vice versa, but the relationship is not significant.
#
# 5. **Moderate Positive Correlation Between `Social Media DL (Bytes)` and `Google DL (Bytes)`**:
#    - The value **0.00696** indicates a weak positive relationship, which means that a slight increase in social media data might correlate with a slight increase in Google data usage, but the correlation is not strong enough to be highly predictive.
#
# 6. **Weak Negative Correlation Between `Email DL (Bytes)` and `Other DL (Bytes)`**:
#    - With a value of **-0.01266**, this suggests a very weak negative correlation. As email data usage increases slightly, `Other DL (Bytes)` decreases marginally, though this relationship is weak and likely not of major significance.
#
# 7. **Moderate Negative Correlation Between `Total UL (Bytes)` and `YouTube DL (Bytes)`**:
#    - The correlation of **-0.00505** indicates a very weak negative relationship, meaning that higher YouTube data usage could slightly lower the uplink data volume, but this relationship is minimal.

# %% [markdown]
# # Dimensionality Reduction (Principal Component Analysis)
